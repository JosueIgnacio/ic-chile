# %%
import pandas as pd
import duckdb

print("pandas:", pd.__version__)
print("duckdb:", duckdb.__version__)
# Out:
# pandas: 2.2.3
# duckdb: 1.1.3

# %%
df = pd.read_csv("../data/bronze/cargadores_sec_raw.csv", sep=";")
print("Filas:", len(df))
print("Columnas:", len(df.columns))
df.head()
# Out:
# Filas: 1711
# Columnas: 28
#    Column1.cantidad_Cargadores  Column1.cargadores.cantidad_Conectores  \
# 0                            2                                       1
# 1                            2                                       1
# 2                            1                                       3
# 3                            1                                       3
# 4                            1                                       3
#
#   Column1.cargadores.conectores.cable Column1.cargadores.conectores.carga  \
# 0                                  NO                                  AC
# 1                                  NO                                  AC
# 2                                  SI                                  DC
# 3                                  SI                                  DC
# 4                                  SI                                  AC
#
#   Column1.cargadores.conectores.identificadorConector  \
# ...
